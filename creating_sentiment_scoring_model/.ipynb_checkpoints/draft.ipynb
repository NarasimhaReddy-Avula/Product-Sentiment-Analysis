# %% [markdown]
# # Creating a Dictionary-based Sentiment Analyzer

# %%
import pandas as pd
import nltk
from IPython.display import display
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Step 1: Loading in the small_corpus .csv file created in the "creating_dataset" milestone.

# %%
reviews = pd.read_csv("../../data/small_corpus.csv")

# %%
reviews.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  reviewerName  \
# 0      1.0      True   01 4, 2016  A3OZQDZD6KIJW8  B00VE6241C  Angry Wombat
# 1      1.0     False  08 10, 2012  A1S4RVJGKE2VI2  B0013OM528   josenewtype
# 2      1.0      True   02 4, 2009  A1GRBUI69G22RX  B000PS1HMM        B Chan
# 3      1.0     False  01 23, 2012   AD3EX5UG7UZPB  B001NJKHWI        Marcos
# 4      1.0     False  09 29, 2015   AFSO322QHIPYE  B00JUFT1F6           cbf
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    reviewText  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The bumpy part is very hard rubber and very slick. These have less grip than the bare dualshock 4 sticks.
# 1                                                                                                                                      I bought these same exact cables on ebay, since I didn't know they had these on amazon. The product itself looks fine, but when you attempt to put it in the ps2 av slot, there is a lot of resistance that isn't normal. Most people here just shoved it in, but I knowing a good amount on computers, I knew that the pins aren't aligned the same way as the official component cables for playstation. So what happens is you bend some pins far off alignment when you shove the thing in. Thus missing the contacts and making the cable unusable. Sometimes if you're lucky it will still work but for me it damaged my av slot on my ps2. I fixed the av slot and bought official component cables and they fit just as fine as the stock composite sony ones.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                               I was not able to download this game on a laptop that is less than 2yrs old.  Furthermore, although I could download on another laptop (only 4 mos old!), it was unable to play.  It seems to me that MoH could sell a lot more games if they would keep in mind users that don't have the latest technology on their PC's.  I've enjoyed previous MoH games, but will now stay away from any new products from this company.
# 3  While I like the type of strategic battle - turn based mixed with grid based movement - i.e. SRPG; I could not get into this game. The feather element is inventive (strategic sacrifice of a party member in battle). The "sin" element is inventive, but feels flawed, for lack of a better term, and makes battles either too hard (usually) or too easy.\nI have a feeling I picked the worst Valkyrie Profile game to start with.\nAside from that: The graphics look like 8 bit or worse!, the story felt REALLY boring to me, and the game, in general, is tedious. The 3rd battle you're in is a bit too difficult for the beginning of the game. I can look past that since eventually I progressed, but the game continued to be, as my title states, and forgive my redundancy, tedious and boring. A big let down for a Square Enix game. Perhaps I'll try my luck with a different V.P. game.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Stuck on verifying available free space during save attempt.  Game is unplayable.
#
#                                 summary  unixReviewTime vote  \
# 0                         Way too slick      1451865600  NaN
# 1               Trust me on this one...      1344556800  NaN
# 2  Only for the latest in PC technology      1233705600  NaN
# 3             Boring, tedious let down.      1327276800    2
# 4                              One Star      1443484800  NaN
#
#                         style image
# 0                         NaN   NaN
# 1                         NaN   NaN
# 2                         NaN   NaN
# 3  {'Format:': ' Video Game'}   NaN
# 4  {'Format:': ' Video Game'}   NaN

# %% [markdown]
# ### Step 2: Tokenizing the sentences and words of the reviews
# Here, We're going to test different versions of word tokenizer on reviews. We'll then decide which tokenizer might be better to use.

# %% [markdown]
# ### Treebank Word Tokenizer

# %%
from nltk.tokenize import TreebankWordTokenizer
from string import punctuation
import string

# %%
tb_tokenizer = TreebankWordTokenizer()

# %%
reviews["rev_text_lower"] = reviews['reviewText'].apply(lambda rev: str(rev)\
                                                        .translate(str.maketrans('', '', punctuation))\
                                                        .replace("<br />", " ")\
                                                        .lower())

# %%
reviews[['reviewText','rev_text_lower']].sample(2)
# Out:
#                                                                                                                                                                                                                                                                reviewText  \
# 2485                                                                                                                                                                                                                                           Worth playing but overated
# 3212  This is an amazing game. Graphics, storyline, gameplay, are all top notch. What really sets it apart from anything else, however, is the atmosphere. I really recommend having a 5 speaker surround sound setup to truly enjoy all the vibe this game has to offer.
#
#                                                                                                                                                                                                                                                   rev_text_lower
# 2485                                                                                                                                                                                                                                  worth playing but overated
# 3212  this is an amazing game graphics storyline gameplay are all top notch what really sets it apart from anything else however is the atmosphere i really recommend having a 5 speaker surround sound setup to truly enjoy all the vibe this game has to offer

# %%
reviews["tb_tokens"] = reviews['rev_text_lower'].apply(lambda rev: tb_tokenizer.tokenize(str(rev)))

# %%
pd.set_option('display.max_colwidth', None)

# %%
reviews[['reviewText','tb_tokens']].sample(3)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    reviewText  \
# 1401                                                                                                                                                                                                                                                                                                                                                                                                                                                                         got this on ps+ free.  the game is so terrible.  the guns are uninspiring.  shooting with it boring too.  the gun handling just does not feel like handling a gun.  ads is slow and glitchy.  visually, graphics does not look good at all.  and frame rate does not feel good too.  at this point, i am just forcing myself to play.  oh man, it is so terrible
# 1452                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     gift
# 2636  I think this game is quite imaginative, and challenging.  I don't know why the story-line is put down.  It is a videogame, and I've certainly seen worse story-lines and voice acting in many videogames I've played. (House of the Dead 2, comes to mind).  I'm not sure why the other reviewers are complaining about the story-line.\n\nThis game features a lovely Asian lady, who has worked as an EMT, and now looks forward to the challenges of working as a race car driver.  How can you beat that?  She has a sexy way about her, that makes her an interesting character to watch, and be influenced by.  Her lack of an accent is sexy as hell, as we watch her shimmy her way into each scenario and race.  We WANT HER TO WIN!!!\n\nI give this one Two very hard thumbs up!  Way up!\n\nMC White said:  Check it out!!!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    tb_tokens
# 1401                                                                                                                                                                                                                                          [got, this, on, ps, free, the, game, is, so, terrible, the, guns, are, uninspiring, shooting, with, it, boring, too, the, gun, handling, just, does, not, feel, like, handling, a, gun, ads, is, slow, and, glitchy, visually, graphics, does, not, look, good, at, all, and, frame, rate, does, not, feel, good, too, at, this, point, i, am, just, forcing, myself, to, play, oh, man, it, is, so, terrible]
# 1452                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [gift]
# 2636  [i, think, this, game, is, quite, imaginative, and, challenging, i, dont, know, why, the, storyline, is, put, down, it, is, a, videogame, and, ive, certainly, seen, worse, storylines, and, voice, acting, in, many, videogames, ive, played, house, of, the, dead, 2, comes, to, mind, im, not, sure, why, the, other, reviewers, are, complaining, about, the, storyline, this, game, features, a, lovely, asian, lady, who, has, worked, as, an, emt, and, now, looks, forward, to, the, challenges, of, working, as, a, race, car, driver, how, can, you, beat, that, she, has, a, sexy, way, about, her, that, makes, her, an, interesting, ...]

# %% [markdown]
# ### Casual Tokenizer

# %%
from nltk.tokenize.casual import casual_tokenize

# %%
reviews['casual_tokens'] = reviews['rev_text_lower'].apply(lambda rev: casual_tokenize(str(rev)))

# %%
reviews[['reviewText','casual_tokens','tb_tokens']].sample(3)
# Out:
#                                                                                                                                reviewText  \
# 300                                                                                                       simply cannot be read. returned
# 2308                                 Boring story and gameplay so far that I've played.  It is not worth the monthly subscription needed.
# 277   Dead out of the box. Did some checking and it turns out the usb cable has a short in it. Not worth buying if it comes dead already.
#
#                                                                                                                                                       casual_tokens  \
# 300                                                                                                                            [simply, cannot, be, read, returned]
# 2308                                             [boring, story, and, gameplay, so, far, that, ive, played, it, is, not, worth, the, monthly, subscription, needed]
# 277   [dead, out, of, the, box, did, some, checking, and, it, turns, out, the, usb, cable, has, a, short, in, it, not, worth, buying, if, it, comes, dead, already]
#
#                                                                                                                                                           tb_tokens
# 300                                                                                                                          [simply, can, not, be, read, returned]
# 2308                                             [boring, story, and, gameplay, so, far, that, ive, played, it, is, not, worth, the, monthly, subscription, needed]
# 277   [dead, out, of, the, box, did, some, checking, and, it, turns, out, the, usb, cable, has, a, short, in, it, not, worth, buying, if, it, comes, dead, already]

# %% [markdown]
# ### Removing StopWords
# This part has been remvoed as removing stop words is not good for sentiment analysis at all!!

# %%
#nltk.download('stopwords')

# %%
#stop_words = nltk.corpus.stopwords.words('english')

# %%
#stop_words.remove("no")

# %%
#stop_words.remove("not")

# %%
#print(stop_words)

# %%
#"not" in stop_words

# %%
#len(stop_words)

# %%
#from string import punctuation
#print(punctuation)

# %%
#reviews['tokens_nosw'] = reviews['tb_tokens'].\
#    apply(lambda words: [w for w in words if w not in stop_words and w not in punctuation and w != ""])

# %%
#reviews[['tb_tokens','tokens_nosw']].sample(3)

# %% [markdown]
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
reviews['tokens_stemmed'] = reviews['tb_tokens'].apply(lambda words: [stemmer.stem(w) for w in words])

# %%
reviews[['tb_tokens','tokens_stemmed']].sample(3)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         tb_tokens  \
# 3095   [ive, probably, played, way, more, animal, crossing, new, leaf, than, is, healthy, for, a, human, but, part, of, the, reason, is, theyve, been, making, neat, little, changes, to, the, game, one, of, those, is, the, introduction, of, these, little, amiibo, this, is, the, rover, amiibo, like, the, other, amiibo, its, adorable, and, heres, how, it, works, 1, at, some, point, after, the, animal, crossing, welcome, amiibo, update, to, your, game, youll, hear, a, voice, calling, out, to, you, follow, that, voice, and, eventually, youll, find, an, aladdinstyled, genie, lamp, on, the, ground, pick, it, up, and, take, it, home, 2, ...]
# 472                                                                                                                                                                               [i, bought, this, game, the, first, day, it, came, out, at, best, buy, i, anticipated, so, much, after, seeing, a, really, cool, tv, commercial, about, it, during, an, nba, game, after, playing, it, though, just, not, my, cup, of, tea, it, gets, old, quickly, just, being, either, cops, or, robbers, in, a, fictional, land, resembling, california, not, a, huge, selection, of, cars, available, either, i, much, prefer, gran, turismo, 5, and, forza, motorsport, 3]
# 1972  [these, sticks, have, the, same, dimensions, and, fit, just, as, the, regular, x1, sticks, but, have, a, few, compromises, the, sticks, that, i, received, are, definitely, a, different, material, than, the, stock, sticks, it, appears, as, more, of, a, grey, instead, of, black, which, isnt, a, huge, deal, but, the, material, feels, way, less, grippy, and, more, plastic, than, the, rubber, feeling, of, the, stock, sticks, i, have, noticed, i, can, not, grip, them, sometimes, or, my, thumbs, slip, off, completely, at, times, i, would, look, at, the, emods, sticks, instead, or, they, would, probably, be, ok, with, some, grips, ...]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           tokens_stemmed
# 3095       [ive, probabl, play, way, more, anim, cross, new, leaf, than, is, healthi, for, a, human, but, part, of, the, reason, is, theyv, been, make, neat, littl, chang, to, the, game, one, of, those, is, the, introduct, of, these, littl, amiibo, thi, is, the, rover, amiibo, like, the, other, amiibo, it, ador, and, here, how, it, work, 1, at, some, point, after, the, anim, cross, welcom, amiibo, updat, to, your, game, youll, hear, a, voic, call, out, to, you, follow, that, voic, and, eventu, youll, find, an, aladdinstyl, geni, lamp, on, the, ground, pick, it, up, and, take, it, home, 2, ...]
# 472                                                                                                                                                                        [i, bought, thi, game, the, first, day, it, came, out, at, best, buy, i, anticip, so, much, after, see, a, realli, cool, tv, commerci, about, it, dure, an, nba, game, after, play, it, though, just, not, my, cup, of, tea, it, get, old, quickli, just, be, either, cop, or, robber, in, a, fiction, land, resembl, california, not, a, huge, select, of, car, avail, either, i, much, prefer, gran, turismo, 5, and, forza, motorsport, 3]
# 1972  [these, stick, have, the, same, dimens, and, fit, just, as, the, regular, x1, stick, but, have, a, few, compromis, the, stick, that, i, receiv, are, definit, a, differ, materi, than, the, stock, stick, it, appear, as, more, of, a, grey, instead, of, black, which, isnt, a, huge, deal, but, the, materi, feel, way, less, grippi, and, more, plastic, than, the, rubber, feel, of, the, stock, stick, i, have, notic, i, can, not, grip, them, sometim, or, my, thumb, slip, off, complet, at, time, i, would, look, at, the, emod, stick, instead, or, they, would, probabl, be, ok, with, some, grip, ...]

# %% [markdown]
# ### Lemmatisation

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag

# %%
def penn_to_wn(tag):
    """
        Convert between the PennTreebank tags to simple Wordnet tags
    """
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

# %%
lemmatizer = WordNetLemmatizer()
def get_lemas(tokens):
    lemmas = []
    for token in tokens:
        pos = penn_to_wn(pos_tag([token])[0][1])
        if pos:
            lemma = lemmatizer.lemmatize(token, pos)
            if lemma:
                lemmas.append(lemma)
    return lemmas

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
reviews['lemmas'] = reviews['tb_tokens'].apply(lambda tokens: get_lemas(tokens))

# %%
reviews[['reviewText','tokens_stemmed','lemmas']].sample(2)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   reviewText  \
# 1782  That was the reaction of my PC to this game. I bought it for cheap, hoping that it was going to be at least as good as the first Far Cry. Boy, was I wrong.\n\nThe game first connected to internet to self-apply updates. "Uh-Oh" I thought, "this usually means trouble". Then the game started - blocky, blotchy rendering, so bad that I could not navigate through the game.\n\nEverything is brown, WHY? The buldings, the grass, the cars, the weapons, everthing. My machine should not throw up when it tries to play this game, what a mess.
# 181                                                                                                                                                                                                                                                                                                                                                                                              What a horrible horrible horrible game. Graphics look like that of 1985. The gameplay sucks the control sucks not a fun game at all do not waste your money
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     tokens_stemmed  \
# 1782  [that, wa, the, reaction, of, my, pc, to, thi, game, i, bought, it, for, cheap, hope, that, it, wa, go, to, be, at, least, as, good, as, the, first, far, cri, boy, wa, i, wrong, the, game, first, connect, to, internet, to, selfappli, updat, uhoh, i, thought, thi, usual, mean, troubl, then, the, game, start, blocki, blotchi, render, so, bad, that, i, could, not, navig, through, the, game, everyth, is, brown, whi, the, buld, the, grass, the, car, the, weapon, everth, my, machin, should, not, throw, up, when, it, tri, to, play, thi, game, what, a, mess]
# 181                                                                                                                                                                                                                                                                                                                                                                                               [what, a, horribl, horribl, horribl, game, graphic, look, like, that, of, 1985, the, gameplay, suck, the, control, suck, not, a, fun, game, at, all, do, not, wast, your, money]
#
#                                                                                                                                                                                                                                                                                                                                                                                                       lemmas
# 1782  [be, reaction, pc, game, i, bought, cheap, hop, be, go, be, least, good, first, far, cry, boy, be, i, wrong, game, first, connect, internet, selfapply, update, uhoh, i, thought, usually, mean, trouble, then, game, start, blocky, blotchy, render, so, bad, i, not, navigate, game, everything, be, brown, buldings, grass, car, weapon, everthing, machine, not, throw, up, try, play, game, mess]
# 181                                                                                                                                                                                                                                                                                [horrible, horrible, horrible, game, graphic, look, gameplay, suck, control, suck, not, fun, game, do, not, waste, money]

# %% [markdown]
# ### Sentiment Predictor Baseline Model

# %%
def get_sentiment_score(tokens):
    score = 0
    tags = pos_tag(tokens)
    for word, tag in tags:
        wn_tag = penn_to_wn(tag)
        if not wn_tag:
            continue
        synsets = wn.synsets(word, pos=wn_tag)
        if not synsets:
            continue
        
        #most common set:
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        
        score += (swn_synset.pos_score() - swn_synset.neg_score())
        
    return score

# %%
nltk.download('sentiwordnet')
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# True

# %%
## test
swn.senti_synset(wn.synsets("perfect", wn.ADJ)[0].name()).pos_score()
# Out:
# 0.625

# %%
reviews['sentiment_score'] = reviews['lemmas'].apply(lambda tokens: get_sentiment_score(tokens))

# %%
reviews[['reviewText','lemmas','sentiment_score']].sample(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         reviewText  \
# 1263                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Between the lagging cheaters and the developer actively hating the player base, it is best to leave this game alone.  I have over two months invested in the game and cannot take the lack of aporeciation from the developer to fix game issues or police the online environment. You have been warned.
# 3948                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  works pefect
# 1190                                                                                                                                                                                                                                                                                                                                                                                                                                               Not worth buying I did not like this at all I read every single review before buying this an they all seem good. But after my 4 year old played it he got bored playing it within 3 minutes an didn't want to touch it since. The games on it are not well crafted.  For this game the price should be 5$. An for a kids learning game it really lack alot of motor skills ....
# 2968  Well this game was worth every penny that I paid for it. My sister also has the game and she enjoys it. I think this is fun for all ages.\n\nGraphics:\n8.5/10\n\n3-D, but not too advanced for its time.\n\nSound:\n9/10\nGreat music selections to obtain.\nEach home brings out a new variety.\n\nControls:\n10/10\nPretty easy.\nYou get the option of using the stylus or the normal controls.\n\nPlayability:\nVery-High\n\nOnline Play:\n6.5/10\nIt's fun, however, with the amount of people who try and wreck havoc on other towns, it lowers the enjoyability.\nJust remember, only let people into your town that you would trust.\n\nOverall:\n9/10\n\nMy recommendation:\n\nSure fire way to lose track of time as you become engulfed in the wonders of your town and the people in it.\n\nGreat for all ages!
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Gundam: Rise From The Ashes: Side Story 0079  is NOT Sonic Adventure
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    lemmas  \
# 1263                                                                                                                                                                                                                                                                                                                                          [lag, cheater, developer, actively, hat, player, base, be, best, leave, game, alone, i, have, month, invest, game, not, take, lack, aporeciation, developer, fix, game, issue, police, online, environment, have, be, warn]
# 3948                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [work, pefect]
# 1190                                                                                                                                                                                                                                                                                                                       [not, worth, buying, i, do, not, i, read, single, review, buying, seem, good, year, old, played, get, bore, play, minute, didnt, want, touch, game, be, not, well, craft, game, price, be, kid, learn, game, really, lack, alot, motor, skill]
# 2968  [well, game, be, worth, penny, i, paid, sister, also, have, game, enjoys, i, think, be, fun, age, graphic, not, too, advanced, time, sound, great, music, selection, obtain, home, brings, new, variety, control, pretty, easy, get, option, use, stylus, normal, control, playability, veryhigh, online, play, fun, however, amount, people, try, wreck, havoc, other, town, lower, enjoyability, just, remember, only, let, people, town, trust, overall, recommendation, sure, fire, way, lose, track, time, become, engulfed, wonder, town, people, great, age]
# 48                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [gundam, rise, ash, side, story, be, not, sonic, adventure]
#
#       sentiment_score
# 1263            0.500
# 3948            0.000
# 1190            1.250
# 2968           -1.125
# 48             -0.250

# %%
reviews[['reviewText','lemmas','sentiment_score']].sample(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      reviewText  \
# 1079                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         The overall feel in the hand of this controller was good, but the quality is not there. I recived this thing a few weeks ago and it is in the garbage as of now. Connectition problem compatibility problems and to top it all off the D-pad wore out already. Very disappointing.
# 4301                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       As a fan of the Tenchu series, I really loved the aspect of Tenchu Z that allowed me to create, well... ME.  And my master was Rikimaru at that!  Tenchu Z gives you the classic Tenchu gameplay, has good customization options available as well as a long mission tree.  A must play for Tenchu fans, as well as ninja fans.  It will also help the gamers out there that are lacking a good stealth game.  Since stealth seems to be an endangered species in 2013.  Thanks to run and gun Call of Duty games.  Yeah, I said it.
# 2857  Originally envisioned as a launch title for the Playstation 3, WarHawk was re-thought from the ground up as a multiplayer-only title that shows some of what the PS3 is capable of.  Naturally, WarHawk is one of the best games to hit the PS3 yet, and is also one of the most fun multiplayer experiences you'll have on a console.  If you remember the original WarHawk (released way, way, way back for the PS1) you can expect some of the same type of gameplay here, only now you aren't just limited to attacking in the air, but you are on foot and in land vehicles as well.  Combine this with the fact the game supports play for 32 players over a horde of different maps and such and you can already see what makes WarHawk so appealing.  The game looks simply amazing, and the controls using the SixAxis controler are spectacular to say the least.  It should also be noted that WarHawk is also available through download at Sony's online Playstation store with a cheaper price tag.  Which version to lay down the cash for is up to you, but the hard copy of WarHawk includes a Bluetooth Headset, which comes in pretty handy considering the game takes full advantage of voice chat options.  Other than that, the only downsides to WarHawk are some slight choppiness and the fact that a single player campaign would have at least been a nice addition for those whose online options aren't immediately available, but then again, the game is geared towards a specific audience after all.  All in all, WarHawk isn't the killer app that PS3 fans have been looking forward to, but it's still a sight to behold on it's own merits, and it's definitely one of the best, exclusive games to hit the PS3 yet.
# 4280                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Great game for online play. The catch is you have to pay for Playstation Plus to play online. Still, $50 for a year of PS Plus isn't too bad. Also gives lots of discounts for other games and even some free games as well. Another catch is there will be packs adding stuff via DLC to the game that must be bought. If this is the first game you want to get for the PS4, I'd recommend getting the Star Wars Battlefront PS4 bundle for $300 (currently on sale)\n\nIf you are a fan of Battlefront 1 & 2 on the PS2 (or XBOX or Gamecube or whatever) then absolutley would love this. Very much like the original 2. Controls are somewhat different, but are great. Flaws are however no campaign and no Galactic Conquest like 1 & 2. And as I said DLC will sucker you. It only has 3 playable heroes (Han, Luke, Leia) and 3 playable villains (Darth Vader, Emperor, Boba Fett) but have to get DLC for more coming out. Also a lot less maps then BF2. Again more on the way via DLC.
# 6                                                                                                                                                After 15 year of waiting for DNF, we get a terrible, out of date, sub-par shooter. Duke Nukem 3D was an amazing game, and I was waiting eagerly for the sequel to finally be released. I was in highschool back then. I'm 29 now. This terrible game has the ignominious reputation of having one of the longest development times for a video game of all time. I'm sorry to report, DNF is not even 1% as good as Duke Nukem 3D.\n\nWhat to say? Terrible level design. 3D Realms designed levels where you literally just walk around without shooting anything. This is supposed to be a first person shooter. Instead you are left wandering around in linear levels where you will hit a proverbial brick wall and then spend an inordinate amount of time wondering what the heck you are supposed to do to advance in the game. What you usually have to do is often contrived and stupid, and it's utterly unfun and boring.\n\nGone are the awesome power-ups from the original game like atomic health or medikits, instead you have a stupid regenerating health system that promotes peek-a-boo gameplay. THAT'S NOT HOW DUKE SHOULD BE. To make matters worse, there's a 2 weapon limit (which was later increased to 4 weapons, but that also has issues).\n\nFinally the graphics are absolutely terrible, and so is the enemy design. To make matters worse, the game is extremely sexist, and offensive. The game tried VERY hard to be shocking in a vain attempt at humor, but it just comes off as completely tasteless. If I could give this game a 0, I would. Do not buy at any price.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    lemmas  \
# 1079                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [overall, feel, hand, controller, be, good, quality, be, not, there, i, recived, thing, few, week, ago, be, garbage, now, connectition, problem, compatibility, problem, top, dpad, wore, already, very, disappoint]
# 4301                                                                                                                                                                                                                                                                                                                                                      [fan, tenchu, series, i, really, love, aspect, tenchu, z, allow, create, well, master, be, rikimaru, tenchu, z, give, classic, tenchu, gameplay, have, good, customization, option, available, well, long, mission, tree, play, tenchu, fan, well, ninja, fan, also, help, gamers, there, be, lack, good, stealth, game, stealth, seem, be, endanger, specie, thanks, run, gun, call, duty, game, yeah, i, say]
# 2857  [originally, envision, launch, title, playstation, warhawk, be, rethought, ground, up, multiplayeronly, title, show, ps3, be, capable, naturally, warhawk, be, best, game, hit, ps3, yet, be, also, most, fun, multiplayer, experience, youll, have, console, remember, original, warhawk, release, way, way, way, back, ps1, expect, same, type, gameplay, here, only, now, arent, just, limited, attack, air, be, foot, land, vehicle, well, combine, fact, game, support, play, player, horde, different, map, such, already, see, make, warhawk, so, appeal, game, look, simply, amaze, control, use, sixaxis, controler, be, spectacular, say, least, also, be, note, warhawk, be, also, available, download, sonys, online, playstation, store, cheaper, ...]
# 4280                                                                     [great, game, online, play, catch, be, have, pay, playstation, play, online, still, year, p, isnt, too, bad, also, give, lot, discount, other, game, even, free, game, well, catch, be, there, be, pack, add, stuff, dlc, game, be, bought, be, first, game, want, get, ps4, id, recommend, get, star, war, battlefront, ps4, bundle, currently, sale, be, fan, battlefront, ps2, xbox, gamecube, then, absolutley, love, very, much, original, control, be, somewhat, different, be, great, flaw, be, however, campaign, galactic, conquest, i, say, dlc, sucker, only, have, playable, hero, han, luke, leia, playable, villain, darth, vader, emperor, boba, fett, have, get, dlc, more, ...]
# 6                                             [year, wait, dnf, get, terrible, date, subpar, shooter, duke, nukem, be, amaze, game, i, be, wait, eagerly, sequel, finally, be, release, i, be, highschool, back, then, im, now, terrible, game, have, ignominious, reputation, have, long, development, time, video, game, time, im, sorry, report, dnf, be, not, even, good, duke, nukem, say, terrible, level, design, realm, design, level, literally, just, walk, shoot, anything, be, suppose, be, first, person, shooter, instead, be, left, wander, linear, level, hit, proverbial, brick, wall, then, spend, inordinate, amount, time, wonder, heck, be, suppose, do, advance, game, usually, have, do, be, often, contrive, stupid, utterly, unfun, boring, ...]
#
#       sentiment_score
# 1079            0.125
# 4301            4.875
# 2857            5.125
# 4280            2.125
# 6               0.000
